# %% [markdown]
# Kaggle data source - https://www.kaggle.com/datasets/therohk/india-headlines-news-dataset
#
# Tfidf logic code reference - https://sci2lab.github.io/ml_tutorial/tfidf/#show_similar_documents

# %%
import os
import re
import time
import pandas as pd
import numpy as np
import datetime
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity 
from sklearn.metrics import pairwise_distances

import seaborn as sns
import matplotlib.pyplot as plt

from search_functions import *

# %%
FILE_PATH = os.path.join('C:\\Users\\Hariharan\\Desktop\\ML Projects','Search using tfidf','data','india-news-headlines.csv')
print(FILE_PATH)
# Out:
# C:\Users\Hariharan\Desktop\ML Projects\Search using tfidf\data\india-news-headlines.csv

# %%
print('Reading the Questions file...')
df = pd.read_csv(FILE_PATH, delimiter=',', encoding='ISO-8859-1')
print('done')
print(df.shape)
# Out:
# Reading the Questions file...
# done
# (3424067, 3)

# %%
print(df.columns)
# Out:
# Index(['publish_date', 'headline_category', 'headline_text'], dtype='object')

# %%
df.drop(columns=['headline_category'],inplace=True)

# %%
df['publish_date'] = df['publish_date'].astype(str)
df['publish_date'] = pd.to_datetime(df['publish_date'], format='%Y-%m-%d')
df['year'] = pd.DatetimeIndex(df['publish_date']).year
df['month'] = pd.DatetimeIndex(df['publish_date']).month
df['day'] = pd.DatetimeIndex(df['publish_date']).day

# %%
data = [preprocess(raw_text) for raw_text in (df['headline_text'])]

df['clean_text'] = data

# %%
df.head()
# Out:
#   publish_date                                      headline_text  year  \
# 0   2001-01-02  Status quo will not be disturbed at Ayodhya; s...  2001
# 1   2001-01-02                Fissures in Hurriyat over Pak visit  2001
# 2   2001-01-02              America's unwanted heading for India?  2001
# 3   2001-01-02                 For bigwigs; it is destination Goa  2001
# 4   2001-01-02               Extra buses to clear tourist traffic  2001
#
#    month  day                                         clean_text
# 0      1    2  status quo will not be disturbed at ayodhya sa...
# 1      1    2                fissures in hurriyat over pak visit
# 2      1    2               america s unwanted heading for india
# 3      1    2                  for bigwigs it is destination goa
# 4      1    2               extra buses to clear tourist traffic

# %%
# %%time 
tfidf_filename = os.path.join('C:\\Users\\Hariharan\\Desktop\\ML Projects','Search using tfidf','model','tfidf.pk')
tfidf_features_filename = os.path.join('C:\\Users\\Hariharan\\Desktop\\ML Projects','Search using tfidf','model','tfidf_features.pk')

tfidf,tfidf_features = refresh_tf_idf_model(df,tfidf_filename,tfidf_features_filename)
# Out:
# Wall time: 1min 25s

# %%
search_text = "CSK"
pairwise_distance = nlp_search(search_text, tfidf_filename, tfidf_features_filename)
filtered_df = format_results(df,pairwise_distance)

# %%
list(filtered_df['headline_text'])
# Out:
# ['Faf du Plessis (CSK)',
#  'Srini forgoes 29% of CSK shares',
#  'Will Trishas fianc buy CSK',
#  'Aniruda Srikkanth (CSK)',
#  'Douglas Bollinger (CSK)',
#  'Will Dhoni do a Buffon for CSK?',
#  'CSK play like champions',
#  'Michael Hussey (CSK)',
#  'IPL 2015 - CSK overcome Morkel scare',
#  'IPL 2015: MI beats CSK',
#  'Durham eye CSK tie-up',
#  "IPL: CSK's unseen moments",
#  'CSK CEO Gurunath Meiyappan arrested',
#  'CSK Charles Shafiq Karthika',
#  'Rajasthan; CSK in needle contest',
#  'Dwayne Bravo (CSK)',
#  'Dwayne Bravo (CSK)',
#  'Scorecard: CSK vs KKR',
#  'Mumbai take on CSK in opener',
#  'Bhavna travels with the CSK team',
#  'Scorecard: CSK vs RCB',
#  'CSK faces hit of Rs 350 crore',
#  'Hope I get a game for CSK: Dirk Nannes',
#  'ipl 2018 rcb vs csk match preview virat kohlis rcb look to break csk jinx',
#  'IPL 2015: CSK vs DD thriller',
#  'RCB vs CSK Highlights; IPL 2019: RCB pull off a thrilling one-run win over CSK',
#  'I want CSK to win: Namitha',
#  'Suresh Raina (CSK)',
#  'CSK vs SRH; IPL Qualifier 1: Focus on Dhoni; Williamson as CSK take on SRH',
#  'CSK loss upsets Sakshi Dhoni',
#  "Dhoni praises Raina after CSK's win",
#  "Dhoni praises Raina after CSK's win",
#  'IPL 2015: Bollywood supports MI and CSK',
#  'Priyanka Chopra gets CSK dancing!',
#  'India Cements to demerge CSK into subsidiary',
#  'Albie; Morris set to miss CSK opener',
#  'Why CSK are bosses of crunch games',
#  'CSK win gives Mumbai favourites tag against T&T',
#  'CSK win gives Mumbai favourites tag against T&T',
#  'Southee set to replace Bollinger in CSK squad',
#  'Raina helps CSK post 174/4 against RCB',
#  'Key moments: Mohit shines for CSK',
#  'CSK ready for another scrap',
#  'CSK make good captains',
#  "IPL 2018: CSK's Jadeja; Harbhajan strangle RCB",
#  "Pics: CSK's journey so far...",
#  'Lucky charms; omens to help CSK win',
#  "'Reloaded' CSK ready for Royals",
#  "I wasn't overawed by reputation of CSK bowlers: Valthaty",
#  'CSK secure reassuring win over MI',
#  'CSK secure reassuring win over MI',
#  'Srinivasan loses CSK to Vibrant Movies',
#  'CSK vs MI: 4 memorable moments',
#  'Rapper Blaaze composes anthem for CSK',
#  'Varun Manian denies plans to buy CSK',
#  "CSK vs SRH; IPL 2018 final preview: Can CSK be 'super' again in title clash against Sunrisers Hyderabad?",
#  'IPL 7: Why CSK are bosses of crunch games',
#  'IPL: CSK; RR - Return of the prodigals',
#  'Clinical CSK hand DD big defeat',
#  'Cauvery stir: Show support; Rajini tells CSK',
#  'CSK vs RCB: When; where; how to follow live 35th IPL match between CSK vs RCB',
#  'Bollinger to replace Oram in CSK squad',
#  'CSK the team to beat',
#  'Badrinath shines; CSK overcome Pune again',
#  'Dhoni; Sachin retained by CSK and MI',
#  'Delhi and CSK square off sans the skippers',
#  'CSK audio on February 28',
#  'Upbeat CSK take on wounded Warriors',
#  "Rajasthan Royals's fate tied with CSK",
#  'KKR vs CSK Highlights; IPL 2019: Suresh Raina; Ravindra Jadeja power CSK to a five-wicket win in Kolkata',
#  'IPL 2019: CSK; DC swap positions in lopsided contest',
#  'IPL 2015: CSK bows down to SRH',
#  'A folksy tribute to CSK by its fans',
#  'Nerveless Raina sets up CSK-KXIP clash',
#  "Struggling KKR face CSK as 'home stretch' begins",
#  "Betting controversy to hit 'Brand CSK'; says experts",
#  'Pressure on CSK to stop Mumbai rampage',
#  'Dhoni; Badrinath late blitzkrieg take CSK to 164/3',
#  'MI vs CSK: Take your pick',
#  'Dhoni-led CSK start as favourite in final',
#  "IPL 2019: CSK's Dhoni formula undone in RCB's one-run win",
#  'Badri unbeaten 52 takes CSK to 151/4 against Central Districts',
#  'KKR vs CSK: Chingri cutlet vs Keerai vada',
#  'Speculation over CSK buyers rise ahead of 2015 auction',
#  'Ranbir supports MI; Sushant cheers CSK',
#  "Fleming hails CSK's blue collar day",
#  'We played perfect cricket against CSK; says Pollard',
#  "Gurunath; once CSK's face; takes another knock",
#  'Flintoff was a good influence on CSK: Fleming',
#  'Flintoff was a good influence on CSK: Fleming',
#  'Rattled KKR up against confident CSK',
#  "IPL 2015: Nehra's magic gives CSK comfortable win",
#  'CSK-RCB showdown opens enticing IPL playoffs',
#  'Injured R Ashwin out for two CSK matches',
#  "I've improved a lot as a cricketer after CSK experience: Jagadeesan",
#  'Murali Vijay spells victory for CSK',
#  "Fleming surprised by CSK's performance",
#  'Down in the dumps; CSK face RCB test',
#  'Pune look for desperate win against CSK',
#  'CSK is the most relaxed team: Pathan',
#  "CSK's reign in Dhoni's den after rain",
#  'Parents to get royal treatment; courtesy CSK',
#  'GC divided as Shastri bats for CSK; RR',
#  'McCullum; Jadeja inspire CSK to No 1',
#  "CSK's Bollinger wins hearts on debut",
#  'Key moments: Jadeja spins CSK to win',
#  'CSK and Royals put first foot forward',
#  'Did CSK pay close to $6m for Jadeja?',
#  "CSK thrive on Suresh Raina's night",
#  "CSK decison positive for India Cements' shareholders",
#  'India Cements shareholders; not Gurunath; own CSK',
#  'CSK eye winning start against re-jigged DD',
#  "Srinivasan forgoes 29% of CSK shares for ex-cricketers' welfare",
#  'Probe CSK-RR May 12; 2013 tie; suggests Mudgal report',
#  'CSK fans go berserk during practice',
#  'Rain threat looms over CSK-Scorchers game',
#  'RCB take on CSK in final league tie',
#  "In pics: CSK's journey in IPL",
#  'Gambhir: CSK defeat difficult to swallow',
#  "CLT20: Marsh takes Lions out of CSK's way",
#  "'Best franchise' CSK braces for doomsday",
#  "CSK done in by wrong 'intelligence'",
#  'We missed our chances; says CSK coach Fleming',
#  "It's a battle between CSK's experience and Daredevils' youth: Viv Richards",
#  'IPL 2018: Faf du Plessis scripts great escape; CSK in final',
#  'Athletic CSK keep RCB at last place',
#  'IPL 7: Recent history makes KXIP favourites against CSK',
#  'MS Dhoni set to leave suspended CSK',
#  'Kochi aim for another upset against CSK',
#  'Gayle-led RCB take on consistent CSK',
#  'We make good captains at CSK; claims Dhoni',
#  'Calm du Plessis crucial for CSK in final',
#  'Hard work; CSK stint helped Mohit get noticed',
#  "Dhoni's CSK on 'slippery ground' vs SA's Titans",
#  'CSK look to keep winning momentum against Daredevils',
#  'CSK look to keep winning momentum against Daredevils',
#  "It'll be CSK gethu again today; say fans",
#  'Kolkata meet CSK in Ranchi as IPL returns home',
#  'Being part of CSK a big learning curve: Dhruv',
#  'IPL 6: RP no-balls RCB as CSK steal a win',
#  'IPL 7: Will SRH stop the CSK juggernaut?',
#  'Hyderabad: Pubs; lounges get ready for CSK-MI clash',
#  'Delhi Daredevils brace for CSK spin attack',
#  "Dhoni's return boosts CSK for Mumbai Indians clash",
#  'CSK look for semis assurance; T&T chase elusive win',
#  'CSK set the blueprint for T20 dominance',
#  'New CSK mantra: Go back to move forward',
#  "Why not shift CSK's home games; ask franchises",
#  'Head to head: KKR vs CSK',
#  "Dhoni lied about Meiyappan's role in CSK; alleges Salve",
#  'Pietersen; Jayawardene bolster Delhi ahead of CSK tie',
#  'Bravo: CSK have belief to win from any situation',
#  "SC wants CSK out of IPL; queers Srinivasan's return pitch",
#  'Allround MI blow away CSK to enter final',
#  'Visitors KKR look for revenge against CSK',
#  'Dropped catches cost us against CSK: Bangar',
#  'CSK sign David Hussey to replace Bravo',
#  'Srinivasan to snap ties with CSK: Reports',
#  'CSK has right combination of pace and spin: Bollinger',
#  'Stephen Fleming likely to head new CSK academy',
#  'IPL 8: Devils hope to keep calm against CSK',
#  'CSK bring down curtains on RCB in IPL 7',
#  'ipl live score rcb vs csk quinton de kock falls after 37 ball 53',
#  "CSK devaluation referred to BCCI's legal cell",
#  'CSK owners India Cement Ltd launches T20 tourney for schools',
#  'Srinivasan decides to snap CSK ties',
#  'Plays of the day: Twin run-outs and a CSK battle',
#  "Depleted Mumbai take on CSK's might in CLT20 opener",
#  'CSK to go for the kill against Kings XI',
#  "'CSK's exit blessing in disguise'",
#  'PWI vs CSK: Time for some Warriors spirit at home',
#  'T&T skipper Ramdin credits bowlers for win over CSK',
#  'CSK vs RR: Highlights of the match',
#  'Humour: Fans celebrate CSK win with these memes',
#  'Gilly; Hayden square off as CSK take on Chargers',
#  "CSK devaluation issue referred to BCCI's legal cell",
#  "'CSK's strength has always been its fans'",
#  'IPL: Lodha panel to pronounce CSK; RR verdict today',
#  'IPL 2019: Rajasthan not throwing in the towel yet; ready to take on CSK',
#  'SC tells Srinivasan to choose between BCCI; CSK',
#  'Dhoni guides CSK to tense last-over win over Royals',
#  'Conspiracy in CSK suspension: Swamy moves HC; alleges injustice',
#  'Dhoni and CSK triumphant as IPL sixes record smashed',
#  'CSK game tested our character and temperament; says Gautam Gambhir',
#  'This ban is harsh; we will contest it: CSK official',
#  "Watch: Raina; Negi star in CSK's crowning glory",
#  'FIR registered; cops to probe RR-CSK match',
#  "RR vs CSK: Jos Buttler's unbeaten 95 keeps Rajasthan Royals alive",
#  "Supreme Court dismisses Swamy's petition on CSK",
#  'I have always been a CSK boy: Mohit Sharma',
#  'IPL 2015: Mumbai Indians outplay CSK for fifth consecutive victory',
#  'IPL 8: CSK on top of table after win over Kings',
#  'IPL 4: MS Dhoni happy with CSK team composition',
#  'Clash of mid-season favourites as CSK take on Royals',
#  'IPL 2018: Shubman slams 57*as KKR thump CSK by six wickets',
#  'IPL 4: CSK elect to bat against KKR',
#  'India Cements to spin off IPL team CSK',
#  'BCCI to discuss valuation of CSK in April 26 meeting',
#  'BCCI changed rule to let Srinivasan own CSK: Muthiah',
#  'HC notice to BCCI on CSK plea against suspension',
#  'CSK vs RCB: Battle of power hitters in offing',
#  'Die-hard Dhoni fan pledges hair if CSK win',
#  'Live blog: Lodha panel to pronounce CSK; RR verdict',
#  'CSK vs HL: Chennai slump to second loss in CLT20',
#  'IPL matches to stay in Chennai; says CSK CEO',
#  'Brendon McCullum happy to be back with CSK core',
#  'CSK look to continue winning run; take on hapless Delhi',
#  'RCB stay afloat after tense win over CSK',
#  'CSK ride over Gurunath fiasco; brace for final',
#  'Daredevils go out all guns blazing against CSK',
#  'Old foes MI; CSK lock horns for IPL silverware',
#  "Nehra's hard work pays off for CSK",
#  'ipl 2018 watson turns back to clock as csk take top spot',
#  'KP still out; DK to lead Daredevils against CSK',
#  'IPL 2018: Resurgent RCB clash with CSK in south derby',
#  'Fans hope CSK will again prove they are the best',
#  'CSK eye third consecutive title as they take on KKR',
#  "Top five CSK; RR players to be 'drafted'",
#  'CLT20: CSK vs KKR in a clash of heavyweights',
#  'Mike Hussey a pillar of strength in CSK',
#  'CSK has upper hand as Rajasthan come visiting',
#  'RCB vs CSK: Spice guaranteed in fire-and-ice contest',
#  'Srikkanth is no longer CSK brand ambassador',
#  'CSK eye revenge against Rajasthan Royals in IPL 8',
#  'IPL 2015: CSK climb to the top after 24-run win over RCB',
#  'Rough desert ride in store for CSK',
#  'IPL: RR take on CSK in battle of supremacy',
#  'Chargers can pull off upset win against CSK: White',
#  'IPL 2018: CSK set to benefit financially from change of venue',
#  'IPL 2015: CSK ride on royal show by McCullum; Jadeja',
#  'RCB to face CSK in a high-voltage IPL encounter',
#  'RCB to face CSK in a high-voltage IPL encounter',
#  'IPL: McCullum happy to be back with CSK core',
#  '1200 cops in place for KXIP-CSK IPL match',
#  'IPL 2015: MI and CSK score over SRH and KXIP',
#  'Shane Watson shapes up for CSK task with PSL form',
#  'IPL 2015: Hogg; Uthappa and Russell shine as KKR beat CSK by seven wickets',
#  'CSK plea: HC gives BCCI more time to respond',
#  "Suresh Raina's CSK thrashes Virat Kohli's RCB",
#  "Champions League Twenty20: Dhoni praises Raina; Hussey after CSK's win",
#  'KKR vs CSK: Rain may play spoilsport',
#  "CSK laboratory; the secret of Mahendra King Dhoni's rise",
#  'IPL 2015: Test of captaincy on cards as RCB face CSK in Qualifier 2',
#  'SMS goof-up says CSK in final - before qualifier',
#  'IPL 2018: Old wine Watson helps CSK adapt to Pune',
#  'CSK coach Fleming backs Ravindra Jadeja to come good',
#  'There was no deal to buy Flintoff: CSK',
#  'SRH look to live up to billing against CSK',
#  "IPL: Albie Morkel's valiant attempt falls short as CSK pull off one-run victory",
#  'Dhoni happy with CSK team composition ahead of IPL opener',
#  'Indian recruits will hold the key in CSK',
#  'In Pics: CSK beat DC to set up IPL 2019 final with MI',
#  'Clash of the table-toppers as CSK take on RCB',
#  'IIT-Madras stumps students with its CSK googly',
#  'RCB vs CSK: Lot at stake for Bangalore and Chennai',
#  'CSK are placed in a tough group; says Stephen Fleming',
#  'KKR vs CSK: Time for KKR to dispel all doubts',
#  'Mumbai Indians eye maiden title as CSK battle to overcome distractions',
#  'Drunk Chandigarh cops guarded Dhoni; CSK team at Taj Hotel',
#  'Hardik Pandya stuns CSK; Mumbai Indians move up',
#  'Denied home-cooked biryani; angry Dhoni leads CSK out of hotel',
#  'CSK vs T&T: Trinidad & Tobago beat Chennai Super Kings by 12 runs',
#  'Kochi aim for another upset; take on defending champs CSK',
#  'IPL 2015: CSK vs RR - Southee gunning for McCullum in big battle',
#  'Act on Mudgal report and disqualify CSK from IPL; SC observes',
#  "Out of 2-year ban; CSK eyes 'old boys' for its 2nd innings",
#  'KKR pull off stunning win over CSK in a pulsating IPL 5 final',
#  'Mocktale: CSK to be given permanent spot in IPL finals',
#  'Young players to suffer most due to CSK; RR ban: Dravid',
#  'CSK can still make it to semi-finals: Hussey',
#  "IPL 11: Suresh Raina's hurriedness won't help CSK; says Kris Srikkanth",
#  'Srinivasan son-in-law answered set of questions; denied official role in CSK',
#  'Death bowling is an area of concern for CSK: Dhoni',
#  'Bookie named MS Dhoni over CSK match: Cop to panel',
#  'CSK look to extend unbeaten home run; take on Deccan',
#  'I would love to be back with CSK: Dwayne Bravo',
#  'IPL 2018: This is how much CSK got as prize money',
#  'CSK vs DD Match highlights: Super Kings beat Daredevils by 13 runs',
#  "SIM used by Guru to place bets was in CSK's name",
#  'Siddharth spends time with spinner CSK R Ashwin and wife Preeti',
#  "CSK's early exit blessing in disguise: MS Dhoni",
#  'CSK take on Hyderabad in battle of near equals',
#  'MI vs CSK: Chennai have tough task at hands against Mumbai',
#  "Loyalty in team selection is CSK's mantra of success: Stephen Fleming",
#  "IPL 2015: It's in-form MI vs mighty CSK in first qualifier",
#  'Dhoni practices with CSK; to take final call on Thursday',
#  'IPL 2018: MS Dhoni leads CSK; SRH-themed team of the tournament',
#  'KKR vs CSK: Knight Riders beat Super Kings by 10 runs (D/L)',
#  "CSK's early exit blessing in disguise; says MS Dhoni",
#  'India; CSK are lucky to have MS Dhoni; says Sunrisers coach Moody',
#  "Uncertainty over ticket sale for KTK's IPL match against CSK",
#  'CSK vs KTK: Chennai Super Kings beat Kochi Tuskers Kerala by 11 runs',
#  'CSK face RCB in IPL 2019 opener as BCCI announces schedule for first 17 games',
#  'Watson; Harbhajan; join practice as CSK train in front of packed crowd',
#  'CSK; RR conflict of interest began way back in 2008',
#  'Clash of Titans as CSK face Mumbai Indians in 1st playoff',
#  'IPL player retention 2018: RCB retain Virat Kohli; MS Dhoni returns to CSK',
#  'With core of team in place; CSK & RR may not bid heavily',
#  'CSK has been challenged for the first time in IPL: Fleming',
#  'CSK vs PWI: Chennai Super Kings beat Pune Warriors by 25 runs',
#  'IPL: Virat Kohli; MS Dhoni set to be retained by RCB and CSK respectively',
#  "Royale battle on cards as CSK look to breach RR's fortress",
#  'IPL 2015: David Warner guides SRH to victory over CSK',
#  'CSK; RCB keen to get back to winning ways',
#  'KTK vs CSK: Kochi Tuskers Kerala beat Chennai Super Kings by 7 wickets',
#  'CSK; RR top five to be drafted into new IPL teams',
#  'IPL 2018: Will play-offs boss Suresh Raina deliver again for CSK?',
#  'IPL 2018; RCB vs CSK Match Highlights: Rayudu and Dhoni floor RCB',
#  "Fans can't wait for BCCI's announcement on CSK's return next season",
#  'MI vs CSK: Mumbai Indians beat Chennai Super Kings by 8 runs',
#  'IPL 2018: CSK have showed us that Sunrisers are beatable - AB de Villiers',
#  'CSK will find it tough on return: Muttiah Muralitharan',
#  'I will be more than happy to be associated with CSK in the upcoming season: Sivamani',
#  "IPL 2015: It's fire versus ice as CSK face RCB in battle for final spot",
#  'CSK look to seal playoff berth; take on Delhi Daredevils',
#  'Pune look for desperate win against CSK to stay afloat in IPL',
#  "'Livid' Dhoni offers to quit as CSK skipper; India Cements VP",
#  "We haven't bowled well at the death; says CSK fielding coach Steve Rixon",
#  'KKR; CSK come face to face for first time in IPL 5',
#  'KXIP vs CSK Preview: Punjab face Chennai in hope to win final league match',
#  'CSK must look at Lungi Ngidi over Dwayne Bravo in death overs: Kris Srikkanth',
#  "It's going to be very difficult against CSK: De Villiers",
#  "IPL 2015: McCullum blazes to season's first ton as CSK beat Sunrisers by 45 runs",
#  'CSK vs DD: Chennai Super Kings beat Delhi Daredevils by 18 runs',
#  'Exclusive - CSK have played like a champion team on return: Suresh Raina',
#  'CSK vs SRH: Chennai Super Kings seal last-ball thriller to go top',
#  'PWI vs CSK: Chennai Super Kings crush Pune Warriors by 8 wickets',
#  'With MS Dhoni and Ambati Rayudu; CSK can chase anything: Kris Srikkanth',
#  'Keen battle on cards as CSK seek to stay in hunt',
#  'IPL 2019; CSK vs RCB: Virat Kohli looks to raid the Super Kings den',
#  'CSK vs RR: Chennai Super Kings beat Rajasthan Royals by 64 runs',
#  'RCB vs CSK; IPL 2019: Odds stacked against Challengers in Sunday blockbuster vs Super Kings',
#  'RCB VS CSK: Bangalore lock horns with Chennai in first playoff',
#  'RCB VS CSK: Bangalore lock horns with Chennai in first playoff',
#  'IPL spot-fixing: Mumbai Police in Chennai to question CSK CEO Meiyappan',
#  "IPL: SC reserves order on Swami's petition to lift CSK ban",
#  'IPL 6 Final: Mumbai Indians eye maiden title as CSK battle to overcome distractions',
#  'MI vs CSK: Mumbai Indians maul Chennai Super Kings by 60 runs',
#  'Not easy to forget eight years at CSK: MS Dhoni',
#  'KKR; CSK; Pune Warriors spend big money on first day',
#  'Future of CSK; Rajasthan Royals uncertain as Supreme Court talks of possible suspension',
#  'RR vs CSK: Chennai Super Kings thrash Rajasthan Royals by 63 runs',
#  'RR vs CSK: Chennai Super Kings beat Rajasthan Royals by 4 wickets',
#  'SRH vs CSK: Dhoni-less Chennai go down by six wickets to Hyderabad',
#  'CSK vs DC: Chennai Super Kings beat Deccan Chargers by 19 runs',
#  'CSK vs RR: Chennai Super Kings thrash Rajasthan Royals by 8 wickets',
#  "IPL 2018: Rishabh Pant looks to build reputation against Dhoni's CSK in dead rubber",
#  'DC vs CSK; IPL 2019: Chennai Super Kings beat Delhi Capitals by six wickets',
#  'IPL final on schedule; no threat to CSK right now: BCCI source',
#  'India Inc biggies eye IPL team as SC panel bars CSK; RR',
#  'After 8 years at CSK; Mahendra Singh Dhoni set to join new IPL team',
#  'After 8 years at CSK; Mahendra Singh Dhoni set to join new IPL team',
#  'CSK vs MI: Mumbai Indians beat Dhoni-less Chennai Super Kings by 46 runs',
#  "No ball: Cauvery protests flush IPL out of Chennai; CSK's home matches shifted to Pune",
#  'RCB vs CSK: Gayle takes Royal Challengers Bangalore to the top',
#  'CSK leap to the top as Delhi Daredevils succumb to 33-run defeat',
#  'CSK vs BH: Chennai Super Kings crush Brisbane Heat to book semifinal berth',
#  'CSK vs MI: Chennai Super Kings beat Mumbai Indians by 6 runs',
#  'CSK have the perfect formula to work as a team: Richards',
#  'ipl 2018 csk vs mi preview point of no return for mumbai indians',
#  'Delhi Capitals aim to crack CSK code for maiden IPL final berth',
#  'Shifting of CSK home ground a sad situation for Chennai fans: Sunil Gavaskar',
#  'CSK enter IPL final for 6th time with thrilling win over RCB',
#  'Heat and dust over CSK devaluation on cards in BCCI Working Committee meeting',
#  'MI vs CSK IPL final: One-run triumph gives Mumbai Indians record fourth IPL title',
#  'CSK vs SS: Sydney Sixers beat Chennai Super Kings by 14 runs in CLT20',
#  'IPL team preview: Pune seek immediate impact banking on CSK model of success',
#  'KXIP vs CSK: Chennai lose against Punjab but hold on to home advantage',
#  'KKR vs CSK: Clinical Chennai Super Kings tame Kolkata Knight Riders',
#  'Swamy moves SC for urgent hearing on plea against ban on CSK',
#  'MI vs CSK: Sensational Mumbai Indians clinch last ball thriller over Chennai Super Kings',
#  "IPL 2019; CSK vs RCB: Onus on MS Dhoni's spinners to stop Virat Kohli & Co.",
#  'Cauvery issue: Actors stage protest in Chennai; Rajinikanth says CSK players must wear black badges',
#  'IPL Qualifier 1: Exciting CSK-SRH battle on the cards for a spot in final',
#  'CSK vs SRH: Shane Watson helps Chennai Super Kings open playoffs door',
#  'CSK vs RCB: Chennai Super Kings beat Royal Challengers Bangalore by 21 runs',
#  'CSK vs RR; IPL 2019: Chennai Super Kings beat Rajasthan Royals to record third successive win',
#  'IPL Qualifier 2 Preview; CSK vs DC: MS Dhoni; Rishabh Pant in battle of finishers',
#  'SRH vs CSK Preview: Sunrisers Hyderabad brace for Chennai Super Kings challenge',
#  'CSK vs MI Highlights; IPL 2019: All-round Mumbai Indians beat Chennai Super Kings by 46 runs',
#  'IPL 2018; CSK vs DD: Chennai Super Kings beat Delhi Daredevils by 13 runs to go top',
#  'CSK vs SRH: Chennai Super Kings beat Sunrisers Hyderabad to win third IPL title',
#  'CSK vs RCB; IPL 2019: Chennai Super Kings beat Royal Challengers Bangalore by 7 wickets',
#  'DC vs CSK: Jadeja special helps Chennai Super Kings thump Deccan Chargers by 74 runs',
#  'IPL 2019 Live streaming: When; where; how to watch and follow CSK vs DC live',
#  'CSK vs KXIP: Kings XI Punjab beat Chennai Super Kings by 7 runs',
#  'IPL auction 2018: Delhi Daredevils bag Glenn Maxwell and Gautam Gambhir; Dwayne Bravo returns to CSK',
#  'CSK vs RCB: Chennai Super Kings beat Royal Challengers Bangalore to win IPL 4',
#  'IPL 2019 Live streaming: When; where; how to watch and follow CSK vs KKR live',
#  'KKR vs CSK: Rain gain for Kolkata Knight Riders against Chennai Super Kings',
#  'IPL 2019 Live streaming: When; where; how to watch and follow CSK vs MI live',
#  'IPL 2019 Live streaming: When; where; how to watch and follow RCB vs CSK live',
#  'IPL 2019 Live streaming: When; where; how to watch and follow RR vs CSK live',
#  'ipl 2018 preview csk vs royals dhoni raina likely to be fit against rajasthan royals',
#  'KXIP vs CSK: Kings XI Punjab beat Chennai Super Kings by 6 wickets',
#  'IPL 2019 Live streaming: When; where; how to watch and follow KXIP vs CSK live',
#  'CSK vs NSW: New South Wales crush Chennai Super Kings by 46 runs to book semifinals berth',
#  'SRH vs CSK: Chennai Super Kings beat Sunrisers Hyderabad to enter IPL final',
#  'CSK vs KKR: Chennai Super Kings strangle Kolkata Knight Riders on a slow deck; top table',
#  'CSK vs SRH Final: Shane Watson century powers Chennai Super Kings to third IPL title',
#  'CSK vs DD Match Preview: Resurgent Delhi Daredevils take on Chennai Super Kings in crucial battle',
#  'IPL 2018; RR vs CSK: Rajasthan Royals keep playoff hopes alive with four-wicket win',
#  'CSK vs MI Qualifier 1: Mumbai Indians tame Chennai Super Kings on vicious turner to make fifth IPL final',
#  'DC vs SRH Highlights: Delhi Capitals beat Sunrisers Hyderabad by 2 wickets to set up Qualifier 2 clash with CSK',
#  'RCB vs CSK: Chris Gayle steers Royal Challengers to a 8-wicket win over Super Kings',
#  'MI vs CSK; IPL 2019 Qualifier 1: Mumbai Indians beat Chennai Super Kings by 6 wickets to make their fifth final']

# %%
filtered_df['year'].nunique()
# Out:
# 13

# %%
# count plot on single categorical variable

if filtered_df['year'].nunique() == 1:
    sns.countplot(x ='year', hue='month', data = filtered_df)
else:
    sns.countplot(x ='year', data = filtered_df)

plt.rcParams['figure.figsize']=30,8
# Show the plot
plt.show()

# %% [markdown]
# # Word cloud generator

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

word_cloud_year = 2016
word_cloud_month = 10
word_cloud_day = 3

wc_df = df.loc[(df['year']==word_cloud_year) & (df['month']==word_cloud_month) & (df['day']==word_cloud_day)]
wc_df = df.loc[(df['year']==word_cloud_year) & (df['month']==word_cloud_month)]
# wc_df = df.loc[(df['year']==word_cloud_year)]


print("Nbr of news items:", wc_df.shape[0])
# Read the whole text.
text = ' '.join(wc_df['headline_text'].tolist())


# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# # the matplotlib way:


# take relative word frequencies into account, lower max_font_size
wordcloud = WordCloud(background_color="white",max_words=len(text),max_font_size=40, relative_scaling=.5).generate(text)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# Nbr of news items: 21689
